# %%
import git
import csv
import numpy as np
from cottools.scc import collect_scc, SccData
from cottools.filesolver import NameRepo
from concernbert.frontend import CdCalculator
from scipy.stats import pearsonr
from datetime import datetime
from collections import defaultdict
from concernbert.frontend import estimate_percentile

# %%
cd_calculator = CdCalculator("_models/EntityBERT-v3_train_nonldl-lr5e5-2_83-e3", "_cache")

# %%
REPO = "_repos/activemq"
repo = git.Repo(REPO, odbt=git.GitCmdObjectDB)
scc_data = collect_scc(REPO)
file_repo = NameRepo.parse_log(REPO, "main")
# Out:
# 100%|██████████| 15066/15066 [00:10<00:00, 1430.94it/s]
#  24%|██▍       | 16812/68806 [00:03<00:12, 4316.17it/s]

# %%
def load_bytes(repo: git.Repo, hexsha: str) -> bytes:
    return repo.odb.stream(bytes.fromhex(hexsha)).read()  # type: ignore

results = []

# %%
latest_commit = file_repo.latest_commit()
for file_id in file_repo.file_ids(latest_commit):
    try:
        file_name = file_repo.file_name_by_id(file_repo.latest_commit(), file_id)
        cont_changes = file_repo.cont_changes_by_id(file_id)

        metrics = defaultdict(list)
        for rev in cont_changes:
            try:
                commit = repo.commit(rev)
                path = file_repo.file_name_by_id(rev, file_id)
                print("Path!!",path)
                obj = commit.tree.join(path)
                if not isinstance(obj, git.Blob):
                    continue

                content = load_bytes(repo, obj.hexsha)
                source = content.decode("utf-8", errors="ignore")
                cd = cd_calculator.calc_cd(source, pbar=False)
                print("Im merging code together")
                metrics['loc'].append(scc_data[obj.hexsha].loc)
                metrics['lloc'].append(scc_data[obj.hexsha].loc)  # reuse if lloc not separated
                metrics['entities'].append(cd.num_entities)
                metrics['intra_cd'].append(cd.intra_cd)
                metrics['inter_cd'].append(cd.inter_cd)
                metrics['cdr_intra'].append(estimate_percentile(cd.intra_cd))
            except Exception:
                continue

        if len(metrics['loc']) < 2:
            continue  # not enough data points

        def safe_corr(x, y):
            try:
                return round(pearsonr(x, y)[0], 3)
            except:
                return ''
        results.append([
            file_name,
            len(metrics['loc']),
            safe_corr(metrics['loc'], metrics['intra_cd']),
            safe_corr(metrics['lloc'], metrics['intra_cd']),
            safe_corr(metrics['entities'], metrics['intra_cd']),
            safe_corr(metrics['loc'], metrics['cdr_intra']),
            safe_corr(metrics['entities'], metrics['cdr_intra']),
        ])
         # Pretty print the current result
         #print("Most recent:",results[-1])
        print(f"Processing: {file_name}")
        print(f"# of Commits: {results[-1][1]}")
        print(f"corr(LOC, IntraCD): {results[-1][2]}")
        print(f"corr(LLOC, IntraCD): {results[-1][3]}")
        print(f"corr(Entities, IntraCD): {results[-1][4]}")
        print(f"corr(LOC, CDR Intra): {results[-1][5]}")
        print(f"corr(Entities, CDR Intra): {results[-1][6]}")
        print("-" * 60)
    except Exception:
        continue
print("Im here!!!")
with open("correlation_metrics_over_time.csv", mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow([
        'File', '# of Commits',
        'corr(LOC, IntraCD)', 'corr(LOC, InterCD)',
        'corr(LLOC, IntraCD)', 'corr(LLOC, InterCD)',
        'corr(Entities, IntraCD)', 'corr(Entities, InterCD)',
         'corr(LOC, CDR Intra)','corr(Entities, CDR Intra)'
    ])
    writer.writerows(results)

print("CSV written to correlation_metrics_over_time.csv")
# Out:
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.txt
# Path!! README.md
# Path!! README.md
# Path!! README.md
# Path!! README.md
# Path!! README.md
# Path!! activemq-core/pom.xml
# /Users/shawnblank/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/shawnblank/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-core/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-unit-tests/pom.xml
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-client/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-client/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-client/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-client/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-client/src/main/grammar/SelectorParser.jj
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# Im merging code together
# Processing: activemq-client/src/main/java/org/apache/activemq/ActiveMQConnection.java
# # of Commits: 193
# corr(LOC, IntraCD): 0.751
# corr(LLOC, IntraCD): 0.751
# corr(Entities, IntraCD): 0.817
# corr(LOC, CDR Intra):
# corr(Entities, CDR Intra):
# ------------------------------------------------------------
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Path!! activemq-client/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# Im merging code together
# Processing: activemq-client/src/main/java/org/apache/activemq/ActiveMQConnectionConsumer.java
# # of Commits: 18
# corr(LOC, IntraCD): 0.714
# corr(LLOC, IntraCD): 0.714
# corr(Entities, IntraCD): 0.765
# corr(LOC, CDR Intra):
# corr(Entities, CDR Intra):
# ------------------------------------------------------------
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# Path!! activemq-core/src/main/java/org/apache/activemq/ActiveMQConnectionFactory.java
# Im merging code together
# ...
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/bin/activemq.bat
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/conf/activemq.xml
# Path!! assembly/src/release/docs/index.html
# Path!! assembly/src/release/docs/index.html
# Path!! assembly/src/release/docs/index.html
# Path!! assembly/src/release/docs/index.html
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/example/conf/activemq.xml
# Path!! assembly/src/release/examples/conf/activemq.xml
# Path!! assembly/src/release/examples/conf/activemq.xml
# Path!! assembly/src/release/example/conf/web.xml
# Path!! assembly/src/release/example/conf/web.xml
# Path!! assembly/src/release/example/conf/web.xml
# Path!! assembly/src/release/example/conf/web.xml
# Path!! assembly/src/release/example/conf/web.xml
# Path!! assembly/src/release/example/conf/web.xml
# Path!! assembly/src/release/examples/conf/web.xml
# Path!! assembly/src/release/userGuide.html
# Path!! assembly/src/release/userGuide.html
# Path!! assembly/src/release/userGuide.html
# Path!! assembly/src/release/user-guide.html
# Path!! assembly/src/release/user-guide.html
# Path!! assembly/src/release/user-guide.html
# Path!! assembly/src/release/user-guide.html
# Path!! assembly/src/release/user-guide.html
# Path!! assembly/src/release/docs/user-guide.html
# Path!! assembly/src/release/docs/user-guide.html
# Path!! assembly/src/release/docs/user-guide.html
# Path!! assembly/src/release/docs/user-guide.html
# Path!! assembly/src/release/var/activemq.log
# Path!! assembly/src/release/data/activemq.log
# Path!! assembly/src/test/org/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# Im merging code together
# Processing: assembly/src/test/java/org/apache/activemq/benchmark/BenchmarkSupport.java
# # of Commits: 14
# corr(LOC, IntraCD): -0.971
# corr(LLOC, IntraCD): -0.971
# corr(Entities, IntraCD): -0.732
# corr(LOC, CDR Intra):
# corr(Entities, CDR Intra):
# ------------------------------------------------------------
# Path!! assembly/src/test/org/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# Im merging code together
# Processing: assembly/src/test/java/org/apache/activemq/benchmark/Consumer.java
# # of Commits: 11
# corr(LOC, IntraCD): -0.969
# corr(LLOC, IntraCD): -0.969
# corr(Entities, IntraCD): nan
# corr(LOC, CDR Intra):
# corr(Entities, CDR Intra):
# ------------------------------------------------------------
# Path!! assembly/src/test/org/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# Im merging code together
# Processing: assembly/src/test/java/org/apache/activemq/benchmark/Producer.java
# # of Commits: 12
# corr(LOC, IntraCD): 0.807
# corr(LLOC, IntraCD): 0.807
# corr(Entities, IntraCD): nan
# corr(LOC, CDR Intra):
# corr(Entities, CDR Intra):
# ------------------------------------------------------------
# Path!! assembly/src/test/org/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/org/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Path!! assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# Im merging code together
# Processing: assembly/src/test/java/org/apache/activemq/benchmark/ProducerConsumer.java
# # of Commits: 11
# corr(LOC, IntraCD): 0.938
# corr(LLOC, IntraCD): 0.938
# corr(Entities, IntraCD): nan
# corr(LOC, CDR Intra):
# corr(Entities, CDR Intra):
# ------------------------------------------------------------
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# Path!! pom.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 19
#      17 content = load_bytes(repo, obj.hexsha)
#      18 source = content.decode("utf-8", errors="ignore")
# ---> 19 cd = cd_calculator.calc_cd(source, pbar=False)
#      20 print("Im merging code together")
#      21 metrics['loc'].append(scc_data[obj.hexsha].loc)
#
# File ~/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/concernbert/frontend.py:38, in CdCalculator.calc_cd(self, source, pbar)
#      37 def calc_cd(self, source: str, *, pbar: bool = False) -> CdResult:
# ---> 38     groups = find_entity_docs(source)
#      39     return self.calc_cd_from_docs(groups, pbar=pbar)
#
# File ~/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/concernbert/semantic.py:300, in find_entity_docs(content)
#     298 captures = _find_captures(content_bytes)
#     299 nodes = [c.node for c in captures.values()]
# --> 300 parents = _to_parents_dict(nodes)
#     301 children = _to_children_dict(parents)
#     302 names = _to_names_dict(captures, children)
#
# File ~/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/concernbert/semantic.py:129, in _to_parents_dict(nodes)
#     127 ids: set[int] = set(n.id for n in nodes)
#     128 for node in nodes:
# --> 129     parents[node] = next((a for a in _iter_ancestors(node) if a.id in ids), None)
#     130 return parents
#
# File ~/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/concernbert/semantic.py:129, in <genexpr>(.0)
#     127 ids: set[int] = set(n.id for n in nodes)
#     128 for node in nodes:
# --> 129     parents[node] = next((a for a in _iter_ancestors(node) if a.id in ids), None)
#     130 return parents
#
# File ~/Documents/Drexel /Research/git/cottools/.venv/lib/python3.12/site-packages/concernbert/semantic.py:119, in _iter_ancestors(node)
#     117 def _iter_ancestors(node: Node) -> Iterable[Node]:
#     118     curr: Node | None = node.parent
# --> 119     while curr is not None:
#     120         yield curr
#     121         curr = curr.parent
#
# KeyboardInterrupt:
